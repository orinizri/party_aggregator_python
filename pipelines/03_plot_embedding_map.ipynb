# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from nlp.plot_utils import create_umap, plot_embedding_map

# %% [markdown]
# ## Combined requests

# %%
df = create_umap("../data/embeddings/combined_requests.npz", "../outputs/combined_requests_clustered.csv")
plot_embedding_map(df, title="Combined Requests: UMAP Cluster Map")
# Out:
# /Users/orikanner/Documents/python/meta_snap_project/snap_table/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# df.groupby("cluster")["request"].apply(lambda x: x.sample(min(5, len(x)))).to_frame()

# %% [markdown]
# ## Song Requests

# %%
song_reqs_df = create_umap("../data/embeddings/song_requests.npz", "../outputs/song_requests_clustered.csv")
plot_embedding_map(song_reqs_df, title="Song Requests: UMAP Cluster Map")
# Out:
# /Users/orikanner/Documents/python/meta_snap_project/snap_table/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# song_reqs_df.groupby("cluster")["request"].apply(lambda x: x.sample(min(3, len(x)))).to_frame()

# %%
# song_reqs_df["cluster"].value_counts().sort_index()

# %% [markdown]
# # Special Requests

# %%
special_reqs_df = create_umap("../data/embeddings/special_requests.npz", "../outputs/special_requests_clustered.csv")
plot_embedding_map(special_reqs_df, title="Special Requests: UMAP Cluster Map")
# Out:
# /Users/orikanner/Documents/python/meta_snap_project/snap_table/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# special_reqs_df.groupby("cluster")["request"].apply(lambda x: x.sample(min(5, len(x)))).to_frame()

# %%
# special_reqs_df["cluster"].value_counts().sort_index()
